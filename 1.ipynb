# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:/Users/PALLE  BALU/OneDrive/Desktop/ch/marksheet.csv")
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
# [250 rows x 9 columns]

# %%
total=df['Maths'] + df['Science'] + df['English']
per= (total/400)*100
df['percentage']=per
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#            avg  percentage
# 0    50.333333       37.75
# 1    36.666667       27.50
# 2    65.000000       48.75
# 3    33.666667       25.25
# 4    23.333333       17.50
# ..         ...         ...
# 245  17.666667       13.25
# 246  23.333333       17.50
# 247  61.666667       46.25
# 248  55.666667       41.75
# 249  45.333333       34.00
#
# [250 rows x 11 columns]

# %%
df['result']=np.where(df['percentage']>=30,'pass','fail')
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#            avg  percentage result
# 0    50.333333       37.75   pass
# 1    36.666667       27.50   fail
# 2    65.000000       48.75   pass
# 3    33.666667       25.25   fail
# 4    23.333333       17.50   fail
# ..         ...         ...    ...
# 245  17.666667       13.25   fail
# 246  23.333333       17.50   fail
# 247  61.666667       46.25   pass
# 248  55.666667       41.75   pass
# 249  45.333333       34.00   pass
#
# [250 rows x 12 columns]

# %%
count=df.groupby(['Gender','result']).size()
count.plot(kind='pie')
# Out:
# <Axes: >

# %%
sec=df.groupby(['Section','result']).size()
sec
# Out:
# Section  result
# A        fail      19
#          pass      60
# B        fail      21
#          pass      58
# C        fail      32
#          pass      60
# dtype: int64
