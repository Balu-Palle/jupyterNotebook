# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:/Users/PALLE  BALU/OneDrive/Desktop/ch/marksheet.csv")
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
# [250 rows x 9 columns]

# %%
total=df['Maths'] + df['Science'] + df['English']
per= (total/400)*100
df['percentage']=per
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      percentage
# 0         37.75
# 1         27.50
# 2         48.75
# ...

# %%
df['result']=np.where(df['percentage']>=30,'pass','fail')
df
# Out:
#       id      Name  Gender  Age Section  Science  English  History  Maths  \
# 0      1   Bronnie  Female   13       C       21       81       62     49
# 1      2    Lemmie    Male   15       B       29       41       17     40
# 2      3     Danya  Female   14       C       12       87       16     96
# 3      4     Denna  Female   14       B       15       53       82     33
# 4      5   Jocelin    Male   14       A       43        6        3     21
# ..   ...       ...     ...  ...     ...      ...      ...      ...    ...
# 245  246    Nickie    Male   13       C       28       15       25     10
# 246  247       Rog  Female   13       B        1        4       68     65
# 247  248      Kaia    Male   15       B       93       48       82     44
# 248  249      Anni  Female   14       B       35       73       66     59
# 249  250  Fernande    Male   15       B       50        8       80     78
#
#      percentage result
# 0         37.75   pass
# 1         27.50   fail
# ...

# %%
count=df.groupby(['Gender','result']).size()
count.plot(kind='pie')
# Out:
# <Axes: >

# %%
sec=df.groupby(['Section','result']).size()
sec
# Out:
# Section  result
# A        fail      19
#          pass      60
# B        fail      21
#          pass      58
# C        fail      32
#          pass      60
# dtype: int64

# %%
l=df.groupby('Section')['result'].apply(
    lambda x: (x=='pass').mean() *100
)
l
# Out:
# Section
# A    75.949367
# B    73.417722
# C    65.217391
# Name: result, dtype: float64

# %%
l.plot(kind='bar')
# Out:
# <Axes: xlabel='Section'>

# %%
grp=df.groupby(['Gender','Section','result']).size()

# %%
#Average marks in each subject 

avg_marks=df[['Maths','Science','English']].mean()

avg_marks.plot(kind='pie')
# Out:
# <Axes: >

# %%
df.groupby('Gender')[['Maths','Science','English']].mean().plot(kind='bar' )
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Section')[['Maths','Science','English']].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Section'>

# %%
mr=df.groupby('Gender')['Maths'].mean()
mr.plot(kind='pie', title='Average Maths Scores by Gender', autopct='%1.2f%%')
# Out:
# <Axes: title={'center': 'Average Maths Scores by Gender'}>

# %%
df.groupby('Gender')['Science'].mean().plot(kind='pie',title='Average Science Scores by Gender',autopct='%1.2f%%')
# Out:
# <Axes: title={'center': 'Average Science Scores by Gender'}>

# %%
df.groupby('Gender')['English'].mean().plot(kind='pie',title='Average English Scores by Gender',autopct='%1.2f%%')
# Out:
# <Axes: title={'center': 'Average English Scores by Gender'}>
